# %%
import pandas as pd
import numpy as np
from datetime import date
from time import time

# %%
df = pd.read_csv('EURUSD-2019.csv', names=['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'DateTime'])
# df.drop('Bob', axis=1, inplace=True)

# %%
# df.to_csv('EURUSD-2019.csv', float_format='%g', index=False)

# %%
names = ['EURJPY', 'EURCHF', 'CHFJPY', 'USDCHF', 'USDCAD']
actions = ['Open', 'High', 'Low', 'Close']
name = 'EURUSD'
df = pd.read_csv(f'scaled/{name}-2019.csv')
df.columns = ['Date', 'Time', f'{name}-Open', f'{name}-High', f'{name}-Low', f'{name}-Close', 'DateTime']
df = df.set_index('DateTime')
start = time()
for name in names:
    print(f'Import {name}')
    _df = pd.read_csv(f'{name}-2019.csv')
    _df.drop('Date', axis=1, inplace=True)
    _df.drop('Time', axis=1, inplace=True)
    
    _df.columns = [f'{name}-Open', f'{name}-High', f'{name}-Low', f'{name}-Close', 'DateTime']
    
    df = df.join(_df.set_index('DateTime'))
df.to_csv(f'Merged_2019.csv', float_format='%g', index=False)
# Out:
# Import EURJPY
# Import EURCHF
# Import CHFJPY
# Import USDCHF
# Import USDCAD

# %%
names = ['EURUSD', 'EURJPY', 'EURCHF', 'CHFJPY', 'USDCHF', 'USDCAD']
actions = ['Open', 'High', 'Low', 'Close']
for name in names:
    _df = pd.read_csv(f'{name}-2019.csv', names=['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Bob'])
    print(f'Import {name} have len : {len(_df)}')
# Out:
# Import EURUSD have len : 372530
# Import EURJPY have len : 372610
# Import EURCHF have len : 371001
# Import CHFJPY have len : 372213
# Import USDCHF have len : 371141
# Import USDCAD have len : 372305

# %%
names = ['EURUSD', 'EURJPY', 'EURJPY', 'EURCHF', 'CHFJPY', 'USDCHF', 'USDCAD']
actions = ['Open', 'High', 'Low', 'Close']
for name in names:
    print(f'Import {name}')
    _df = pd.read_csv(f'{name}-2019.csv', names=['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Bob'])
    _df.drop('Bob', axis=1, inplace=True)
    _df['DateTime'] = _df[['Date', 'Time']].agg('-'.join, axis=1)
    _df.to_csv(f'{name}-2019.csv', float_format='%g', index=False)
# Out:
# Import EURJPY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c071dcb7b65f> in <module>
#       5     _df = pd.read_csv(f'{name}-2019.csv', names=['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Bob'])
#       6     for idx, row in _df.iterrows():
# ----> 7         _df.loc[idx,'DateTime'] = row['Date'] + row['Time']
#       8     _df.to_csv(f'{name}-2019.csv', float_format='%g', index=False)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1027                 # scalar
#    1028                 for item in labels:
# -> 1029                     setter(item, value)
#    1030
#    1031         else:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in setter(item, v)
#     964
#     965                 # reset the sliced object if unique
# --> 966                 self.obj[item] = s
#     967
#     968             # we need an iterable, with a ndim of at least 1
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1088             blk_locs = blklocs[val_locs.indexer]
#    1089             if blk.should_store(value):
# -> 1090                 blk.set(blk_locs, value_getitem(val_locs))
#    1091             else:
#    1092                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in set(self, locs, values)
#     374         None
#     375         """
# --> 376         self.values[locs] = values
#     377
#     378     def delete(self, loc):
#
# KeyboardInterrupt:

# %%
len(df.dropna())
# Out:
# 372390

# %%
df
# Out:
#                         Date   Time  EURUSD-Open  EURUSD-High  EURUSD-Low  \
# DateTime
# 2019.01.01-17:02  2019.01.01  17:02      1.14598      1.14599     1.14598
# 2019.01.01-17:03  2019.01.01  17:03      1.14598      1.14607     1.14598
# 2019.01.01-17:04  2019.01.01  17:04      1.14607      1.14607     1.14606
# 2019.01.01-17:05  2019.01.01  17:05      1.14606      1.14621     1.14606
# 2019.01.01-17:06  2019.01.01  17:06      1.14619      1.14666     1.14604
# ...                      ...    ...          ...          ...         ...
# 2019.12.31-16:55  2019.12.31  16:55      1.12117      1.12118     1.12115
# 2019.12.31-16:56  2019.12.31  16:56      1.12118      1.12120     1.12115
# 2019.12.31-16:57  2019.12.31  16:57      1.12115      1.12115     1.12105
# 2019.12.31-16:58  2019.12.31  16:58      1.12105      1.12110     1.12099
# 2019.12.31-16:59  2019.12.31  16:59      1.12099      1.12115     1.12076
#
#                   EURUSD-Close  EURJPY-Open  EURJPY-High  EURJPY-Low  \
# DateTime
# 2019.01.01-17:02       1.14598          NaN          NaN         NaN
# 2019.01.01-17:03       1.14607          NaN          NaN         NaN
# 2019.01.01-17:04       1.14606          NaN          NaN         NaN
# 2019.01.01-17:05       1.14621          NaN          NaN         NaN
# 2019.01.01-17:06       1.14665      125.692      125.692     125.692
# ...                        ...          ...          ...         ...
# 2019.12.31-16:55       1.12118      121.835      121.844     121.835
# 2019.12.31-16:56       1.12115      121.843      121.862     121.843
# 2019.12.31-16:57       1.12105      121.853      121.856     121.846
# 2019.12.31-16:58       1.12099      121.850      121.857     121.820
# 2019.12.31-16:59       1.12076          NaN          NaN         NaN
#
#                   EURJPY-Close  ...  CHFJPY-Low  CHFJPY-Close  USDCHF-Open  \
# DateTime                        ...
# 2019.01.01-17:02           NaN  ...         NaN           NaN          NaN
# 2019.01.01-17:03           NaN  ...         NaN           NaN          NaN
# 2019.01.01-17:04           NaN  ...         NaN           NaN          NaN
# 2019.01.01-17:05           NaN  ...         NaN           NaN      0.98120
# 2019.01.01-17:06       125.692  ...     111.627       111.627      0.98111
# ...                        ...  ...         ...           ...          ...
